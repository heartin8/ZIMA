# %% [markdown]
# <a href="https://colab.research.google.com/github/heartin8/ZIMA/blob/main/example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Please update the information, and submit your work

# %%
my_name = "Xisrav Aslonov"

# %%
my_enrollment_number = "A8"

# %%
my_hobby = "Watching films, Reading Books"

# %%
print("Hello, my name is {}, and my enrollment number is {}. I like {}.".format(my_name, my_enrollment_number, my_hobby))
# Out:
# Hello, my name is Xisrav Aslonov, and my enrollment number is A8. I like Watching films, Reading Books.
